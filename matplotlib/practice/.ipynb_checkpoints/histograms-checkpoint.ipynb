# %% [markdown]
# ### Create a histogram of 1000 points with bins = 40

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.random.randn(1000)
# print (x)
fig ,ax = plt.subplots()
ax.hist(x,bins=40)
ax.set_ylabel("frequency")
ax.set_xlabel("value")

plt.show()

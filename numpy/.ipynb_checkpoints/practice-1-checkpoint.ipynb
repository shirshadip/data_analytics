# %% [markdown]
# ## Weather data analytics

# %% [markdown]
# a numpy array of 365 days daily temparature

# %%
import numpy as np 
temp = np.random.randint(15,45,size=365)
print ("the temparature of 365 days is:\n",temp)
# Out:
# the temparature of 365 days is:
#  [31 27 43 44 30 22 33 32 15 28 33 29 32 16 36 42 31 32 44 20 33 18 15 22
#  43 37 21 17 24 24 33 28 16 42 15 37 37 42 32 21 43 22 15 39 37 17 38 37
#  41 43 22 36 39 29 19 17 33 15 42 29 22 16 17 38 28 38 28 25 30 18 34 19
#  36 35 28 37 30 32 21 24 21 15 37 35 33 30 43 33 18 43 42 32 16 15 29 19
#  34 25 24 16 17 37 37 26 34 19 19 20 44 23 16 35 26 17 34 40 36 26 38 31
#  24 44 38 41 28 37 31 32 33 31 28 23 22 16 27 39 21 23 36 36 25 28 18 40
#  40 43 27 16 37 19 25 20 32 35 24 18 23 20 16 31 19 39 20 40 26 37 35 24
#  36 35 41 39 20 41 22 16 26 27 39 35 21 24 27 31 40 35 42 44 40 28 16 42
#  36 25 15 33 35 18 33 40 43 35 25 22 25 18 31 41 21 22 17 36 16 37 29 38
#  36 36 19 38 15 40 18 29 34 33 17 34 25 31 44 41 27 25 16 23 40 16 35 23
#  23 22 31 15 39 43 25 22 24 39 21 17 17 32 19 26 26 33 44 20 16 26 33 19
#  26 41 41 31 43 31 24 39 37 31 29 26 44 30 38 33 22 35 31 37 19 36 30 20
#  22 39 32 39 26 29 41 40 23 27 40 29 24 30 21 31 37 40 35 36 40 21 28 29
#  35 21 23 33 30 22 32 41 37 43 32 44 34 21 17 32 41 24 21 31 28 38 17 26
#  42 27 16 17 19 25 22 40 37 37 26 21 29 38 31 18 43 36 39 27 32 15 30 27
#  24 26 44 16 37]

# %% [markdown]
# ### lets find the hottest temperature and the coolest tempetrature

# %%
hot = temp.max()
cool=temp.min()
print ("the hottest temparature of a day:",hot,"degree celcius in day no.",temp.argmax())
print ("the coolest temparature of a day:",cool,"degree celcius in day no.",temp.argmin())
# Out:
# the hottest temparature of a day: 44 degree celcius in day no. 83
# the coolest temparature of a day: 15 degree celcius in day no. 27

# %% [markdown]
# ## average temparature

# %%
avg=0
index=0
for days in temp:
    avg = temp.mean()
    # print("the avg temp is:", avg)
    index+=1
print ("the avg tem is :",round(avg,2),f"degree celcius of {index} days")
# Out:
# the avg tem is : 29.45 degree celcius of 365 days
